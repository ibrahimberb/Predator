# %%
from src.helpers.helpers_analysis.justify_sampling import (
    MutationJustifier
)

# %%
TRAINING_DATA_PATH = "../../processed_data_740.csv"

# Reflect changes in the modules immediately.
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# A,x, için B ve C interactor'ları olsun.
# A,y için D ve E interactor'ları olsun.
#
# protein, interactor yaparsan common interactor yok ki..
#
# ama yapman gereken B-C, B-D, B-E, C-D,C-E arasında corelasyon hesaplayıp bir variable'e eklemen. sonra ortalama gösterebilirsin..

# %%
mutation_justifier = MutationJustifier(TRAINING_DATA_PATH)
# Out:
#   0%|          | 0/164 [00:00<?, ?it/s]
# 2022-06-19 11:57:57 | DEBUG    | src.helpers.helpers_analysis.justify_sampling | skip (110, 438)
# 2022-06-19 11:57:57 | DEBUG    | src.helpers.helpers_analysis.justify_sampling | skip (110, 492)
# 2022-06-19 11:57:57 | DEBUG    | src.helpers.helpers_analysis.justify_sampling | skip (110, 549)
# 2022-06-19 11:57:57 | DEBUG    | src.helpers.helpers_analysis.justify_sampling | skip (438, 492)
# 2022-06-19 11:57:57 | DEBUG    | src.helpers.helpers_analysis.justify_sampling | skip (438, 549)
# 2022-06-19 11:57:57 | DEBUG    | src.helpers.helpers_analysis.justify_sampling | skip (492, 549)
# 2022-06-19 11:57:57 | DEBUG    | src.helpers.helpers_analysis.justify_sampling | len(corr_score_values)=0
# 2022-06-19 11:57:57 | CRITICAL | src.helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 110                      0     O00311     I99T                Q9UBU7
# ...

# %%
mutation_justifier.export_data("mutation_justifier")
# Out:
# 2022-06-19 11:58:24 | DEBUG    | src.helpers.helpers_analysis.justify_sampling | Exporting data mutation_justifier ..
# 2022-06-19 11:58:24 | INFO     | src.helpers.helpers_analysis.justify_sampling | mutation_justifier_2022-06-19.csv is exported successfully.

# %%
mutation_justifier.unique_proteins_corr_data["PEARSON_CORR"].value_counts()
# Out:
# HAS ONLY ONE INTERACTOR ACROSS ALL MUTATIONS    90
# NOT APPLICABLE                                  39
# 1.0                                              8
# 0.99                                             6
# 0.98                                             5
# 0.84                                             2
# 0.94                                             2
# 0.97                                             2
# 0.46                                             1
# 0.57                                             1
# 0.63                                             1
# 0.48                                             1
# 0.86                                             1
# 0.52                                             1
# 0.7                                              1
# 0.62                                             1
# 0.81                                             1
# 0.93                                             1
# Name: PEARSON_CORR, dtype: int64
