# %% [markdown]
# # Disruptive Interactions For Each Patient
#
# For each patient, disruptive predicted interactions will be displayed.
#
# **Example**
#
# * `TCGA-XXXX-XXXX-XX`:

# %%
import os.path as op

from helpers.helpers_analysis.interactions_per_patient import InteractionsPerPatient

# Predictions
BRCA_PREDICTION_ID = "ed35a3a3/"
BRCA_PREDICTIONS_COMMON_PATH = "../data/predictions_datasets/brca_prediction_2022-06-17/" + BRCA_PREDICTION_ID
PREDICTION_BRCA_REDUCED_PATH = BRCA_PREDICTIONS_COMMON_PATH + "predictions_soft_2022-06-17.csv"

COAD_PREDICTION_ID = "84fd283a/"
COAD_PREDICTIONS_COMMON_PATH = "../data/predictions_datasets/coad_prediction_2022-06-17/" + COAD_PREDICTION_ID
PREDICTION_COAD_REDUCED_PATH = COAD_PREDICTIONS_COMMON_PATH + "predictions_soft_2022-06-17.csv"

ESCA_PREDICTION_ID = "f2d1e99a/"
ESCA_PREDICTIONS_COMMON_PATH = "../data/predictions_datasets/esca_prediction_2022-06-17/" + ESCA_PREDICTION_ID
PREDICTION_ESCA_REDUCED_PATH = ESCA_PREDICTIONS_COMMON_PATH + "predictions_soft_2022-06-17.csv"

GBM_PREDICTION_ID = "8d7f7caa/"
GBM_PREDICTIONS_COMMON_PATH = "../data/predictions_datasets/gbm_prediction_2022-06-17/" + GBM_PREDICTION_ID
PREDICTION_GBM_REDUCED_PATH = GBM_PREDICTIONS_COMMON_PATH + "predictions_soft_2022-06-17.csv"

HNSC_PREDICTION_ID = "76f498d9/"
HNSC_PREDICTIONS_COMMON_PATH = "../data/predictions_datasets/hnsc_prediction_2022-06-17/" + HNSC_PREDICTION_ID
PREDICTION_HNSC_REDUCED_PATH = HNSC_PREDICTIONS_COMMON_PATH + "predictions_soft_2022-06-17.csv"

OV_PREDICTION_ID = "865d1897/"
OV_PREDICTIONS_COMMON_PATH = "../data/predictions_datasets/ov_prediction_2022-06-17/" + OV_PREDICTION_ID
PREDICTION_OV_REDUCED_PATH = OV_PREDICTIONS_COMMON_PATH + "predictions_soft_2022-06-17.csv"


# ELASPIC Core and Interface datasets
ELASPIC_RESULTS_COMMON_PATH = "../data/Elaspic_merged_results/"  # elaspic_results_datasets

BRCA_CORE_PATH = ELASPIC_RESULTS_COMMON_PATH + "BRCA_Core_2021-11-17.txt"
BRCA_INTERFACE_PATH = ELASPIC_RESULTS_COMMON_PATH + "BRCA_Interface_2021-11-17.txt"

COAD_CORE_PATH = ELASPIC_RESULTS_COMMON_PATH + "COAD_Core_2022-01-06.txt"
COAD_INTERFACE_PATH = ELASPIC_RESULTS_COMMON_PATH + "COAD_Interface_2022-01-06.txt"

ESCA_CORE_PATH = ELASPIC_RESULTS_COMMON_PATH + "ESCA_Core_2021-11-17.txt"
ESCA_INTERFACE_PATH = ELASPIC_RESULTS_COMMON_PATH + "ESCA_Interface_2021-11-17.txt"

GBM_CORE_PATH = ELASPIC_RESULTS_COMMON_PATH + "GBM_Core_2021-11-17.txt"
GBM_INTERFACE_PATH = ELASPIC_RESULTS_COMMON_PATH + "GBM_Interface_2021-11-17.txt"

HNSC_CORE_PATH = ELASPIC_RESULTS_COMMON_PATH + "HNSC_Core_2021-11-17.txt"
HNSC_INTERFACE_PATH = ELASPIC_RESULTS_COMMON_PATH + "HNSC_Interface_2021-11-17.txt"

OV_CORE_PATH = ELASPIC_RESULTS_COMMON_PATH + "OV_Core_2021-11-17.txt"
OV_INTERFACE_PATH = ELASPIC_RESULTS_COMMON_PATH + "OV_Interface_2021-11-17.txt"


# SNV_PATHS
SNV_COMMON_PATH = "../data/snv_datasets"
BRCA_SNV_PATH = op.join(SNV_COMMON_PATH, "SNV_BRCA_hg38_2021-09-22.csv")
COAD_SNV_PATH = op.join(SNV_COMMON_PATH, "SNV_COAD_hg38_2021-09-22.csv")
ESCA_SNV_PATH = op.join(SNV_COMMON_PATH, "SNV_ESCA_hg38_2021-09-22.csv")
GBM_SNV_PATH = op.join(SNV_COMMON_PATH, "SNV_GBM_hg38_2021-09-22.csv")
HNSC_SNV_PATH = op.join(SNV_COMMON_PATH, "SNV_HNSC_hg38_2021-09-22.csv")
OV_SNV_PATH = op.join(SNV_COMMON_PATH, "SNV_OV_hg38_2021-09-22.csv")

# Reflect changes in the modules immediately.
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## BRCA

# %% [markdown]
# ### Instantiate the Class `InteractionsPerPatient`

# %%
brca_interactions_per_patient = InteractionsPerPatient(
    tcga="BRCA",
    prediction_data_path=PREDICTION_BRCA_REDUCED_PATH,
    tcga_snv_path=BRCA_SNV_PATH,
    elaspic_core_path=BRCA_CORE_PATH,
    elaspic_interface_path=BRCA_INTERFACE_PATH,
    identifier="uniprot",
    verbose=False,
)
# Out:
# 2022-06-17 11:37:39 | INFO     | helpers.helpers_analysis.interactions_per_patient | Loading materials ..
# 2022-06-17 11:37:39 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading SNV data simplified ..
# 2022-06-17 11:37:39 | INFO     | helpers.helpers_analysis.loaders | Loading BRCA SNV datasets ..
# 2022-06-17 11:37:46 | DEBUG    | helpers.helpers_analysis.loaders | BRCA SNV data size: (120988, 121)
# 2022-06-17 11:37:46 | DEBUG    | helpers.helpers_analysis.loaders | BRCA SNV data processed size: (60251, 121)
# 2022-06-17 11:37:46 | INFO     | helpers.helpers_analysis.loaders | BRCA SNV datasets are loaded.
# 2022-06-17 11:37:46 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient ids ..
# 2022-06-17 11:37:46 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient to snv_data ..
#   0%|          | 0/985 [00:00<?, ?it/s]
# ...

# %%
brca_interactions_per_patient.print_disruptive_interactions_per_patient()
# Out:
# TCGA-D8-A1XY -> [('Q9UKS6', 'R24H', 'Q9BY11'), ('Q9UKS6', 'R24H', 'Q9UNF0'), ('Q9UKS6', 'R24H', 'Q5TZC3'), ('Q9UKS6', 'R24H', 'Q6FIA3')]
# TCGA-AO-A0J5 -> [('P42336', 'H1047R', 'P27986'), ('P42336', 'H1047R', 'O00459'), ('P42336', 'H1047R', 'P43403')]
# TCGA-A8-A093 -> [('Q15842', 'E237K', 'Q14654'), ('Q15842', 'E237K', 'P63252')]
# TCGA-C8-A133 -> []
# TCGA-AQ-A54O -> []
# TCGA-A8-A07G -> [('P42336', 'H1047R', 'P27986'), ('P42336', 'H1047R', 'O00459'), ('P42336', 'H1047R', 'P43403')]
# TCGA-LD-A74U -> [('P42336', 'C420R', 'Q92569'), ('P42336', 'C420R', 'P27986'), ('P42336', 'C420R', 'O00459'), ('O43684', 'D117G', 'Q12834'), ('Q9UL54', 'V301M', 'P52564')]
# TCGA-OL-A5RV -> [('Q01196', 'G95R', 'Q13951')]
# TCGA-AR-A24V -> []
# TCGA-PL-A8LX -> []
# TCGA-BH-A0W5 -> [('P42336', 'H1047R', 'P27986'), ('P42336', 'H1047R', 'O00459'), ('P42336', 'H1047R', 'P43403')]
# ...

# %%
brca_interactions_per_patient.construct_analysis_table()
# Out:
# 2022-06-17 11:51:16 | INFO     | helpers.helpers_analysis.interactions_per_patient | Constructing the analysis table ..
#   0%|          | 0/985 [00:00<?, ?it/s]
# TCGA-D8-A1XY	Q9UKS6	R24H	All interactors: ['Q9BY11', 'Q9UNF0', 'Q5TZC3', 'Q6FIA3']	I
# ----------------------------------------------------------------------------------------------------
# TCGA-AO-A0J5	P42336	H1047R	All interactors: ['Q13535', 'P27986', 'O00459', 'P43403']	I
# ----------------------------------------------------------------------------------------------------
# TCGA-A8-A093	P28062	R216W	All interactors: ['P40306']	I
# TCGA-A8-A093	Q15842	E237K	All interactors: ['Q14654', 'P63252']	I
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ...

# %%
brca_interactions_per_patient.analysis_table.head()
# Out:
#         PATIENT    PROTEIN_GENE MUTATION  \
# 0  TCGA-D8-A1XY  Q9UKS6:PACSIN3     R24H
# 1  TCGA-AO-A0J5   P42336:PIK3CA   H1047R
# 2  TCGA-A8-A093    P28062:PSMB8    R216W
# 3  TCGA-A8-A093    Q15842:KCNJ8    E237K
# 4  TCGA-A8-A07G   P42336:PIK3CA   H1047R
#
#                                          INTERACTORS  NUM_INTERACTORS  \
# 0  Q9BY11:PACSIN1,Q9UNF0:PACSIN2,Q5TZC3:PACSIN1,Q...                4
# 1  Q13535:ATR,P27986:PIK3R1,O00459:PIK3R2,P43403:...                4
# 2                                      P40306:PSMB10                1
# 3                         Q14654:KCNJ11,P63252:KCNJ2                2
# 4  Q13535:ATR,P27986:PIK3R1,O00459:PIK3R2,P43403:...                4
#
#                               DISRUPTIVE_INTERACTORS  \
# 0  Q9BY11:PACSIN1:0.53,Q9UNF0:PACSIN2:0.62,Q5TZC3...
# 1  P27986:PIK3R1:0.6,O00459:PIK3R2:0.59,P43403:ZA...
# 2
# 3               Q14654:KCNJ11:0.52,P63252:KCNJ2:0.58
# 4  P27986:PIK3R1:0.6,O00459:PIK3R2:0.59,P43403:ZA...
#
# ...

# %%
brca_interactions_per_patient.extract(folder="../data/patient_interaction_datasets")
# Out:
# 2022-06-17 11:57:59 | INFO     | helpers.helpers_analysis.interactions_per_patient | ../data/patient_interaction_datasets\BRCA_patient_interactions_analysis_table_2022-06-17.xlsx is exported.

# %% [markdown]
# ## ESCA

# %% [markdown]
# ### Instantiate the Class `InteractionsPerPatient`

# %%
esca_interactions_per_patient = InteractionsPerPatient(
    tcga="ESCA",
    prediction_data_path=PREDICTION_ESCA_REDUCED_PATH,
    tcga_snv_path=ESCA_SNV_PATH,
    elaspic_core_path=ESCA_CORE_PATH,
    elaspic_interface_path=ESCA_INTERFACE_PATH,
    identifier="uniprot",
    verbose=False,
)
# Out:
# 2022-06-17 11:58:06 | INFO     | helpers.helpers_analysis.interactions_per_patient | Loading materials ..
# 2022-06-17 11:58:06 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading SNV data simplified ..
# 2022-06-17 11:58:06 | INFO     | helpers.helpers_analysis.loaders | Loading ESCA SNV datasets ..
# 2022-06-17 11:58:08 | DEBUG    | helpers.helpers_analysis.loaders | ESCA SNV data size: (45313, 121)
# 2022-06-17 11:58:08 | DEBUG    | helpers.helpers_analysis.loaders | ESCA SNV data processed size: (19497, 121)
# 2022-06-17 11:58:08 | INFO     | helpers.helpers_analysis.loaders | ESCA SNV datasets are loaded.
# 2022-06-17 11:58:08 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient ids ..
# 2022-06-17 11:58:08 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient to snv_data ..
#   0%|          | 0/184 [00:00<?, ?it/s]
# ...

# %%
esca_interactions_per_patient.print_disruptive_interactions_per_patient()
# Out:
# TCGA-KH-A6WC -> []
# TCGA-VR-A8ET -> []
# TCGA-LN-A49W -> [('O00238', 'Y395D', 'Q13153'), ('O00238', 'Y395D', 'O95747'), ('P04637', 'R273C', 'Q13625'), ('P04637', 'R273C', 'P62993'), ('P04637', 'R273C', 'Q96KQ4'), ('P04637', 'R273C', 'Q8WUF5'), ('P04637', 'R273C', 'Q06187')]
# TCGA-IG-A4QS -> [('P61088', 'E61K', 'Q9UNE7'), ('P61088', 'E61K', 'Q86YT6')]
# TCGA-LN-A49N -> [('Q9NPD8', 'S101Y', 'Q8N448'), ('Q9NPD8', 'S101Y', 'Q9NW38'), ('Q9NPD8', 'S101Y', 'P35227'), ('Q9NPD8', 'S101Y', 'P78317'), ('Q9NPD8', 'S101Y', 'B5MCZ6'), ('O14807', 'D67N', 'Q92565'), ('O14807', 'D67N', 'Q8TEU7'), ('O14807', 'D67N', 'P55196'), ('O14807', 'D67N', 'Q07889')]
# TCGA-L5-A43I -> [('Q86UR5', 'K1590M', 'P21579'), ('O95071', 'R2712C', 'P61077'), ('P62330', 'D97N', 'O43665')]
# TCGA-IG-A97I -> [('P04637', 'R248Q', 'Q13625'), ('P04637', 'R248Q', 'Q96KQ4'), ('P04637', 'R248Q', 'P07948'), ('P04637', 'R248Q', 'Q06187')]
# TCGA-IG-A7DP -> []
# ...

# %%
esca_interactions_per_patient.construct_analysis_table()
# Out:
# 2022-06-17 12:03:51 | INFO     | helpers.helpers_analysis.interactions_per_patient | Constructing the analysis table ..
#   0%|          | 0/184 [00:00<?, ?it/s]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# TCGA-LN-A49W	O00238	Y395D	All interactors: ['Q13153', 'O95747']	I
# TCGA-LN-A49W	P04637	R273C	All interactors: ['Q13625', 'P62993', 'Q96KQ4', 'Q8WUF5', 'Q06187']	I
# ----------------------------------------------------------------------------------------------------
# TCGA-IG-A4QS	P61088	E61K	All interactors: ['P38398', 'Q96PU5', 'Q9Y4L5', 'Q9Y3C5', 'Q9C035', 'Q9UNE7', 'Q86Y13', 'O76064', 'Q86YT6', 'O43164', 'Q9H9V4', 'Q6ZSG1', 'O95714']	I
# TCGA-IG-A4QS	P51828	N379S	All interactors: ['O43306', 'O60503']	I
# ----------------------------------------------------------------------------------------------------
# ...

# %%
esca_interactions_per_patient.analysis_table.head()
# Out:
#         PATIENT   PROTEIN_GENE MUTATION  \
# 0  TCGA-LN-A49W  O00238:BMPR1B    Y395D
# 1  TCGA-LN-A49W    P04637:TP53    R273C
# 2  TCGA-IG-A4QS   P61088:UBE2N     E61K
# 3  TCGA-IG-A4QS   P51828:ADCY7    N379S
# 4  TCGA-LN-A49N   Q9NPD8:UBE2T    S101Y
#
#                                          INTERACTORS  NUM_INTERACTORS  \
# 0                           Q13153:PAK1,O95747:OXSR1                2
# 1  Q13625:TP53BP2,P62993:GRB2,Q96KQ4:PPP1R13B,Q8W...                5
# 2  P38398:BRCA1,Q96PU5:NEDD4L,Q9Y4L5:RNF115,Q9Y3C...               13
# 3                          O43306:ADCY6,O60503:ADCY9                2
# 4  Q8N448:LNX2,Q8TEB7:RNF128,Q9NW38:FANCL,P35227:...                6
#
#                               DISRUPTIVE_INTERACTORS  \
# 0                  Q13153:PAK1:0.8,O95747:OXSR1:0.87
# 1  Q13625:TP53BP2:0.95,P62993:GRB2:0.75,Q96KQ4:PP...
# 2                 Q9UNE7:STUB1:0.67,Q86YT6:MIB1:0.54
# 3
# 4  Q8N448:LNX2:0.74,Q9NW38:FANCL:0.77,P35227:PCGF...
#
# ...

# %%
esca_interactions_per_patient.extract(folder="../data/patient_interaction_datasets")
# Out:
# 2022-06-17 12:04:01 | INFO     | helpers.helpers_analysis.interactions_per_patient | ../data/patient_interaction_datasets\ESCA_patient_interactions_analysis_table_2022-06-17.xlsx is exported.

# %% [markdown]
# ## OV

# %% [markdown]
# ### Instantiate the Class `InteractionsPerPatient`

# %%
ov_interactions_per_patient = InteractionsPerPatient(
    tcga="OV",
    prediction_data_path=PREDICTION_OV_REDUCED_PATH,
    tcga_snv_path=OV_SNV_PATH,
    elaspic_core_path=OV_CORE_PATH,
    elaspic_interface_path=OV_INTERFACE_PATH,
    identifier="uniprot",
    verbose=False,
)
# Out:
# 2022-06-17 12:04:03 | INFO     | helpers.helpers_analysis.interactions_per_patient | Loading materials ..
# 2022-06-17 12:04:03 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading SNV data simplified ..
# 2022-06-17 12:04:03 | INFO     | helpers.helpers_analysis.loaders | Loading OV SNV datasets ..
# 2022-06-17 12:04:07 | DEBUG    | helpers.helpers_analysis.loaders | OV SNV data size: (75168, 121)
# 2022-06-17 12:04:07 | DEBUG    | helpers.helpers_analysis.loaders | OV SNV data processed size: (38486, 121)
# 2022-06-17 12:04:07 | INFO     | helpers.helpers_analysis.loaders | OV SNV datasets are loaded.
# 2022-06-17 12:04:08 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient ids ..
# 2022-06-17 12:04:08 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient to snv_data ..
#   0%|          | 0/436 [00:00<?, ?it/s]
# ...

# %%
ov_interactions_per_patient.print_disruptive_interactions_per_patient()
# Out:
# TCGA-61-2092 -> [('P42336', 'H1047R', 'P27986'), ('P42336', 'H1047R', 'O00459'), ('P42336', 'H1047R', 'P43403'), ('Q9NRM7', 'K672I', 'O96017'), ('Q9NRM7', 'K672I', 'Q96GD4'), ('Q13619', 'D750N', 'Q8IWE4'), ('Q13619', 'D750N', 'Q96GG9')]
# TCGA-36-2540 -> []
# TCGA-24-1467 -> [('P34897', 'F501V', 'P34896')]
# TCGA-13-0923 -> [('P08134', 'D59E', 'P52565'), ('P62993', 'A3V', 'Q9H8V3'), ('P62993', 'A3V', 'Q14155'), ('O75175', 'Q684H', 'Q9NZN8'), ('O75175', 'Q684H', 'B2RDX7'), ('O75175', 'Q684H', 'B3KTL6'), ('O75175', 'Q684H', 'F8VV52')]
# TCGA-25-1313 -> [('P00742', 'I451M', 'P00740'), ('P00742', 'I451M', 'P35237'), ('P00742', 'I451M', 'P10646'), ('P00742', 'I451M', 'P05154'), ('Q9BVG8', 'R451H', 'F5H4I9'), ('P04156', 'G131R', 'Q53YK7'), ('Q9NQ66', 'E539K', 'Q9BRC7')]
# TCGA-29-2432 -> []
# TCGA-13-0724 -> [('Q9Y6Q5', 'R251C', 'Q9BXS5')]
# TCGA-61-1995 -> []
# TCGA-61-1998 -> [('P07948', 'F490S', 'Q9UBS0'), ('P06737', 'N254I', 'P11216')]
# ...

# %%
ov_interactions_per_patient.construct_analysis_table()
# Out:
# 2022-06-17 12:09:32 | INFO     | helpers.helpers_analysis.interactions_per_patient | Constructing the analysis table ..
#   0%|          | 0/436 [00:00<?, ?it/s]
# TCGA-61-2092	P42336	H1047R	All interactors: ['Q13535', 'P27986', 'O00459', 'P43403']	I
# TCGA-61-2092	Q9NRM7	K672I	All interactors: ['O96017', 'Q96GD4']	I
# TCGA-61-2092	Q13619	D750N	All interactors: ['Q6PH85', 'Q92564', 'Q8IWE4', 'Q96GG9', 'Q9BTE7']	I
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# TCGA-24-1467	P34897	F501V	All interactors: ['P34896']	I
# ----------------------------------------------------------------------------------------------------
# TCGA-13-0923	P08134	D59E	All interactors: ['P52565']	I
# TCGA-13-0923	P62993	A3V	All interactors: ['Q9H8V3', 'Q14155']	I
# TCGA-13-0923	O75175	Q684H	All interactors: ['Q9NZN8', 'B2RDX7', 'B3KTL6', 'F8VV52']	I
# ...

# %%
ov_interactions_per_patient.analysis_table.head()
# Out:
#         PATIENT   PROTEIN_GENE MUTATION  \
# 0  TCGA-61-2092  P42336:PIK3CA   H1047R
# 1  TCGA-61-2092   Q9NRM7:LATS2    K672I
# 2  TCGA-61-2092   Q13619:CUL4A    D750N
# 3  TCGA-24-1467   P34897:SHMT2    F501V
# 4  TCGA-13-0923    P08134:RHOC     D59E
#
#                                          INTERACTORS  NUM_INTERACTORS  \
# 0  Q13535:ATR,P27986:PIK3R1,O00459:PIK3R2,P43403:...                4
# 1                          O96017:CHEK2,Q96GD4:AURKB                2
# 2  Q6PH85:DCUN1D2,Q92564:DCUN1D4,Q8IWE4:DCUN1D3,Q...                5
# 3                                       P34896:SHMT1                1
# 4                                     P52565:ARHGDIA                1
#
#                               DISRUPTIVE_INTERACTORS  \
# 0  P27986:PIK3R1:0.6,O00459:PIK3R2:0.59,P43403:ZA...
# 1                O96017:CHEK2:0.93,Q96GD4:AURKB:0.77
# 2            Q8IWE4:DCUN1D3:0.67,Q96GG9:DCUN1D1:0.57
# 3                                  P34896:SHMT1:0.71
# ...

# %%
ov_interactions_per_patient.extract(folder="../data/patient_interaction_datasets")
# Out:
# 2022-06-17 12:09:55 | INFO     | helpers.helpers_analysis.interactions_per_patient | ../data/patient_interaction_datasets\OV_patient_interactions_analysis_table_2022-06-17.xlsx is exported.

# %% [markdown]
# ## HNSC

# %% [markdown]
# ### Instantiate the Class `InteractionsPerPatient`

# %%
hnsc_interactions_per_patient = InteractionsPerPatient(
    tcga="HNSC",
    prediction_data_path=PREDICTION_HNSC_REDUCED_PATH,
    tcga_snv_path=HNSC_SNV_PATH,
    elaspic_core_path=HNSC_CORE_PATH,
    elaspic_interface_path=HNSC_INTERFACE_PATH,
    identifier="uniprot",
    verbose=False,
)
# Out:
# 2022-06-17 12:09:55 | INFO     | helpers.helpers_analysis.interactions_per_patient | Loading materials ..
# 2022-06-17 12:09:55 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading SNV data simplified ..
# 2022-06-17 12:09:55 | INFO     | helpers.helpers_analysis.loaders | Loading HNSC SNV datasets ..
# 2022-06-17 12:09:59 | DEBUG    | helpers.helpers_analysis.loaders | HNSC SNV data size: (102309, 121)
# 2022-06-17 12:10:00 | DEBUG    | helpers.helpers_analysis.loaders | HNSC SNV data processed size: (54883, 121)
# 2022-06-17 12:10:00 | INFO     | helpers.helpers_analysis.loaders | HNSC SNV datasets are loaded.
# 2022-06-17 12:10:00 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient ids ..
# 2022-06-17 12:10:00 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient to snv_data ..
#   0%|          | 0/507 [00:00<?, ?it/s]
# ...

# %%
hnsc_interactions_per_patient.print_disruptive_interactions_per_patient()
# Out:
# TCGA-T2-A6X0 -> []
# TCGA-CN-5364 -> [('Q13485', 'R361H', 'B7Z5N5'), ('Q13485', 'R361H', 'Q68DB7'), ('Q13485', 'R361H', 'Q53XR6'), ('Q9Y566', 'R2148H', 'Q9BYB0')]
# TCGA-CV-7090 -> [('Q9UDY2', 'I650F', 'Q14160'), ('Q9UDY2', 'I650F', 'A0PJK8'), ('P04637', 'R273H', 'Q13625'), ('P04637', 'R273H', 'P62993'), ('P04637', 'R273H', 'Q96KQ4'), ('P04637', 'R273H', 'Q8WUF5'), ('P04637', 'R273H', 'Q06187')]
# TCGA-CR-6482 -> []
# TCGA-CR-6473 -> []
# TCGA-CV-5978 -> [('P25103', 'T124M', 'P25101'), ('P25103', 'T124M', 'P34981'), ('Q15700', 'H163Y', 'P29475'), ('P98174', 'N559K', 'P60953')]
# TCGA-CQ-6225 -> [('P15173', 'A125T', 'Q02363'), ('P15173', 'A125T', 'Q02535'), ('Q9H172', 'E311Q', 'P45844'), ('P04637', 'C176S', 'O15350'), ('P04637', 'C176S', 'Q96KQ7'), ('O75175', 'I674M', 'Q9NZN8'), ('O75175', 'I674M', 'B2RDX7'), ('O75175', 'I674M', 'B3KTL6'), ('O75175', 'I674M', 'F8VV52')]
# ...

# %%
hnsc_interactions_per_patient.construct_analysis_table()
# Out:
# 2022-06-17 12:19:20 | INFO     | helpers.helpers_analysis.interactions_per_patient | Constructing the analysis table ..
#   0%|          | 0/507 [00:00<?, ?it/s]
# ----------------------------------------------------------------------------------------------------
# TCGA-CN-5364	Q8N4C7	E242K	All interactors: ['P61764', 'Q68CM6']	I
# TCGA-CN-5364	Q13485	R361H	All interactors: ['B7Z5N5', 'Q68DB7', 'Q53XR6']	I
# TCGA-CN-5364	Q9Y566	R2148H	All interactors: ['Q9BYB0']	I
# ----------------------------------------------------------------------------------------------------
# TCGA-CV-7090	O15116	L87I	All interactors: ['Q9Y333']	I
# TCGA-CV-7090	Q9UDY2	I650F	All interactors: ['Q14160', 'A0PJK8']	I
# TCGA-CV-7090	P04637	R273H	All interactors: ['Q13625', 'P62993', 'Q96KQ4', 'Q8WUF5', 'Q06187']	I
# TCGA-CV-7090	P00492	R48H	All interactors: ['Q9NRG1']	I
# ----------------------------------------------------------------------------------------------------
# ...

# %%
hnsc_interactions_per_patient.analysis_table.head()
# Out:
#         PATIENT   PROTEIN_GENE MUTATION  \
# 0  TCGA-CN-5364   Q8N4C7:STX19    E242K
# 1  TCGA-CN-5364   Q13485:SMAD4    R361H
# 2  TCGA-CN-5364  Q9Y566:SHANK1   R2148H
# 3  TCGA-CV-7090    O15116:LSM1     L87I
# 4  TCGA-CV-7090    Q9UDY2:TJP2    I650F
#
#                                       INTERACTORS  NUM_INTERACTORS  \
# 0                     P61764:STXBP1,Q68CM6:STXBP1                2
# 1  B7Z5N5:SMAD2,Q68DB7:DKFZp781O1323,Q53XR6:SMAD2                3
# 2                                   Q9BYB0:SHANK3                1
# 3                                     Q9Y333:LSM2                1
# 4                       Q14160:SCRIB,A0PJK8:SCRIB                2
#
#                               DISRUPTIVE_INTERACTORS  \
# 0
# 1  B7Z5N5:SMAD2:0.56,Q68DB7:DKFZp781O1323:0.52,Q5...
# 2                                 Q9BYB0:SHANK3:0.83
# 3
# 4                 Q14160:SCRIB:0.6,A0PJK8:SCRIB:0.64
#
#    NUM_DISRUPTIVE_INTERACTORS   NON_DISRUPTIVE_INTERACTORS  \
# ...

# %%
hnsc_interactions_per_patient.extract(folder="../data/patient_interaction_datasets")
# Out:
# 2022-06-17 12:20:08 | INFO     | helpers.helpers_analysis.interactions_per_patient | ../data/patient_interaction_datasets\HNSC_patient_interactions_analysis_table_2022-06-17.xlsx is exported.

# %% [markdown]
# ## GBM

# %% [markdown]
# ### Instantiate the Class `InteractionsPerPatient`

# %%
gbm_interactions_per_patient = InteractionsPerPatient(
    tcga="GBM",
    prediction_data_path=PREDICTION_GBM_REDUCED_PATH,
    tcga_snv_path=GBM_SNV_PATH,
    elaspic_core_path=GBM_CORE_PATH,
    elaspic_interface_path=GBM_INTERFACE_PATH,
    identifier="uniprot",
    verbose=False,
)
# Out:
# 2022-06-17 12:20:08 | INFO     | helpers.helpers_analysis.interactions_per_patient | Loading materials ..
# 2022-06-17 12:20:08 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading SNV data simplified ..
# 2022-06-17 12:20:08 | INFO     | helpers.helpers_analysis.loaders | Loading GBM SNV datasets ..
# 2022-06-17 12:20:12 | DEBUG    | helpers.helpers_analysis.loaders | GBM SNV data size: (82765, 121)
# 2022-06-17 12:20:12 | DEBUG    | helpers.helpers_analysis.loaders | GBM SNV data processed size: (46847, 121)
# 2022-06-17 12:20:12 | INFO     | helpers.helpers_analysis.loaders | GBM SNV datasets are loaded.
# 2022-06-17 12:20:12 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient ids ..
# 2022-06-17 12:20:12 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient to snv_data ..
#   0%|          | 0/392 [00:00<?, ?it/s]
# ...

# %%
gbm_interactions_per_patient.print_disruptive_interactions_per_patient()
# Out:
# TCGA-06-5413 -> []
# TCGA-28-1755 -> [('Q969V5', 'V303G', 'P62837'), ('Q969V5', 'V303G', 'O14933'), ('Q969V5', 'V303G', 'P63279'), ('Q969V5', 'V303G', 'Q96B02'), ('Q969V5', 'V303G', 'P51965'), ('Q969V5', 'V303G', 'P61077'), ('Q969V5', 'V303G', 'Q969T4'), ('Q969V5', 'V303G', 'Q5VVX9'), ('Q969V5', 'V303G', 'P51668'), ('Q969V5', 'V303G', 'Q9Y2X8'), ('Q969V5', 'V303G', 'D6RAH7'), ('O14682', 'S68R', 'Q14145'), ('Q9GZV9', 'H52Y', 'P21802'), ('Q9GZV9', 'H52Y', 'P11362'), ('Q8TEB1', 'R338H', 'Q8NHY2')]
# TCGA-32-1986 -> []
# TCGA-19-4065 -> []
# TCGA-06-0876 -> [('P04637', 'R248W', 'Q13625'), ('P04637', 'R248W', 'P62993'), ('P04637', 'R248W', 'Q9H3D4'), ('P04637', 'R248W', 'Q96KQ4'), ('P04637', 'R248W', 'Q8WUF5'), ('P04637', 'R248W', 'P07948'), ('P04637', 'R248W', 'Q06187'), ('P04637', 'R248W', 'H2EHT1'), ('P04637', 'R248W', 'K7PPA8')]
# TCGA-12-1598 -> [('P06340', 'L71Q', 'P13765'), ('P06340', 'L71Q', 'Q5QNS2')]
# TCGA-76-4927 -> []
# ...

# %%
gbm_interactions_per_patient.construct_analysis_table()
# Out:
# 2022-06-17 12:27:26 | INFO     | helpers.helpers_analysis.interactions_per_patient | Constructing the analysis table ..
#   0%|          | 0/392 [00:00<?, ?it/s]
# ----------------------------------------------------------------------------------------------------
# TCGA-28-1755	Q969V5	V303G	All interactors: ['P62837', 'O14933', 'P63279', 'Q96B02', 'P51965', 'P61077', 'Q969T4', 'Q5VVX9', 'P51668', 'Q9Y2X8', 'D6RAH7']	I
# TCGA-28-1755	Q969K4	N142K	All interactors: ['Q13618']	I
# TCGA-28-1755	O14682	S68R	All interactors: ['Q14145']	I
# TCGA-28-1755	Q9UBU9	K444T	All interactors: ['Q9UKK6', 'P61970', 'Q9NPJ8']	I
# TCGA-28-1755	Q9GZV9	H52Y	All interactors: ['P21802', 'P11362']	I
# TCGA-28-1755	Q8TEB1	R338H	All interactors: ['Q8NHY2']	I
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ...

# %%
gbm_interactions_per_patient.analysis_table.head()
# Out:
#         PATIENT  PROTEIN_GENE MUTATION  \
# 0  TCGA-28-1755   Q969V5:MUL1    V303G
# 1  TCGA-28-1755  Q969K4:ABTB1    N142K
# 2  TCGA-28-1755   O14682:ENC1     S68R
# 3  TCGA-28-1755   Q9UBU9:NXF1    K444T
# 4  TCGA-28-1755  Q9GZV9:FGF23     H52Y
#
#                                          INTERACTORS  NUM_INTERACTORS  \
# 0  P62837:UBE2D2,O14933:UBE2L6,P63279:UBE2I,Q96B0...               11
# 1                                        Q13618:CUL3                1
# 2                                       Q14145:KEAP1                1
# 3               Q9UKK6:NXT1,P61970:NUTF2,Q9NPJ8:NXT2                3
# 4                          P21802:FGFR2,P11362:FGFR1                2
#
#                               DISRUPTIVE_INTERACTORS  \
# 0  P62837:UBE2D2:0.93,O14933:UBE2L6:0.81,P63279:U...
# 1
# 2                                   Q14145:KEAP1:0.6
# 3
# 4                P21802:FGFR2:0.64,P11362:FGFR1:0.51
#
#    NUM_DISRUPTIVE_INTERACTORS            NON_DISRUPTIVE_INTERACTORS  \
# ...

# %%
gbm_interactions_per_patient.extract(folder="../data/patient_interaction_datasets")
# Out:
# 2022-06-17 12:27:54 | INFO     | helpers.helpers_analysis.interactions_per_patient | ../data/patient_interaction_datasets\GBM_patient_interactions_analysis_table_2022-06-17.xlsx is exported.

# %% [markdown]
# # COAD

# %% [markdown]
# ### Instantiate the Class `InteractionsPerPatient`

# %%
coad_interactions_per_patient = InteractionsPerPatient(
    tcga="COAD",
    prediction_data_path=PREDICTION_COAD_REDUCED_PATH,
    tcga_snv_path=COAD_SNV_PATH,
    elaspic_core_path=COAD_CORE_PATH,
    elaspic_interface_path=COAD_INTERFACE_PATH,
    identifier="uniprot",
    verbose=False,
)
# Out:
# 2022-06-17 12:27:54 | INFO     | helpers.helpers_analysis.interactions_per_patient | Loading materials ..
# 2022-06-17 12:27:54 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading SNV data simplified ..
# 2022-06-17 12:27:54 | INFO     | helpers.helpers_analysis.loaders | Loading COAD SNV datasets ..
# 2022-06-17 12:28:05 | DEBUG    | helpers.helpers_analysis.loaders | COAD SNV data size: (264786, 121)
# 2022-06-17 12:28:06 | DEBUG    | helpers.helpers_analysis.loaders | COAD SNV data processed size: (126470, 121)
# 2022-06-17 12:28:06 | INFO     | helpers.helpers_analysis.loaders | COAD SNV datasets are loaded.
# 2022-06-17 12:28:06 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient ids ..
# 2022-06-17 12:28:06 | DEBUG    | helpers.helpers_analysis.interactions_per_patient | Loading patient to snv_data ..
#   0%|          | 0/399 [00:00<?, ?it/s]
# ...

# %%
coad_interactions_per_patient.print_disruptive_interactions_per_patient()
# Out:
# TCGA-AA-3966 -> [('P62873', 'S334I', 'Q13371'), ('Q9UK17', 'A16T', 'Q9NS61'), ('P15313', 'A428T', 'P21281'), ('P35251', 'V921A', 'P35250'), ('P15056', 'V600E', 'P53667'), ('P15056', 'V600E', 'Q13177'), ('Q13905', 'A931S', 'P17081'), ('Q05329', 'C446Y', 'Q99259'), ('Q6ZMN7', 'V435G', 'Q8N448'), ('P14649', 'G97D', 'P60660'), ('P14649', 'G97D', 'Q9Y4I1'), ('P14649', 'G97D', 'A8CDT9'), ('P14649', 'G97D', 'F8WE88'), ('P14649', 'G97D', 'G3V394'), ('P61224', 'T35M', 'O00522'), ('P61224', 'T35M', 'Q8WWW0'), ('P61224', 'T35M', 'O15211'), ('P61224', 'T35M', 'P47736'), ('P61224', 'T35M', 'A4D1F7'), ('Q9H0E7', 'L412P', 'Q70CQ1'), ('O75843', 'M91T', 'P61966'), ('O75843', 'M91T', 'P56377'), ('P05362', 'M91T', 'B2RAL6'), ('P05107', 'P192H', 'P11215'), ('P05107', 'P192H', 'P20702'), ('P05107', 'P192H', 'H3BN02'), ('P51795', 'R293H', 'B3KRR2')]
# TCGA-AD-6901 -> [('Q92736', 'T1107M', 'Q15413'), ('O00141', 'A324T', 'Q13164'), ('O00757', 'R16C', 'P09467'), ('O00757', 'R16C', 'Q2TU34')]
# ...

# %%
coad_interactions_per_patient.construct_analysis_table()
# Out:
# 2022-06-17 13:04:50 | INFO     | helpers.helpers_analysis.interactions_per_patient | Constructing the analysis table ..
#   0%|          | 0/399 [00:00<?, ?it/s]
# TCGA-AA-3966	P62873	S334I	All interactors: ['Q13371']	I
# TCGA-AA-3966	Q9UK17	A16T	All interactors: ['Q9NS61']	I
# TCGA-AA-3966	P15313	A428T	All interactors: ['P21281']	I
# TCGA-AA-3966	O75716	E38Q	All interactors: ['Q14680']	I
# TCGA-AA-3966	Q9BXB4	N590D	All interactors: ['Q96SU4']	I
# TCGA-AA-3966	P35251	V921A	All interactors: ['P35250']	I
# TCGA-AA-3966	P08123	K1248N	All interactors: ['P25940']	I
# TCGA-AA-3966	P15056	V600E	All interactors: ['P53667', 'Q13177']	I
# TCGA-AA-3966	O43543	E71D	All interactors: ['O15315']	I
# TCGA-AA-3966	P20594	A106V	All interactors: ['P23582', 'P01160']	C
# TCGA-AA-3966	Q13905	A931S	All interactors: ['P17081']	I
# TCGA-AA-3966	Q05329	C446Y	All interactors: ['Q99259']	I
# TCGA-AA-3966	Q6ZMN7	V435G	All interactors: ['Q8N448']	I
# ...

# %%
coad_interactions_per_patient.analysis_table.head()
# Out:
#         PATIENT     PROTEIN_GENE MUTATION      INTERACTORS  NUM_INTERACTORS  \
# 0  TCGA-AA-3966      P62873:GNB1    S334I      Q13371:PDCL                1
# 1  TCGA-AA-3966     Q9UK17:KCND3     A16T    Q9NS61:KCNIP2                1
# 2  TCGA-AA-3966  P15313:ATP6V1B1    A428T  P21281:ATP6V1B2                1
# 3  TCGA-AA-3966     O75716:STK16     E38Q      Q14680:MELK                1
# 4  TCGA-AA-3966   Q9BXB4:OSBPL11    N590D    Q96SU4:OSBPL9                1
#
#   DISRUPTIVE_INTERACTORS  NUM_DISRUPTIVE_INTERACTORS  \
# 0       Q13371:PDCL:0.54                           1
# 1      Q9NS61:KCNIP2:0.7                           1
# 2   P21281:ATP6V1B2:0.66                           1
# 3                                                  0
# 4                                                  0
#
#   NON_DISRUPTIVE_INTERACTORS  NUM_NON_DISRUPTIVE_INTERACTORS  \
# 0                                                          0
# 1                                                          0
# ...

# %%
coad_interactions_per_patient.extract(folder="../data/patient_interaction_datasets")
# Out:
# 2022-06-17 13:07:41 | INFO     | helpers.helpers_analysis.interactions_per_patient | ../data/patient_interaction_datasets\COAD_patient_interactions_analysis_table_2022-06-17.xlsx is exported.

# %% [markdown]
# ---
